# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/My Drive/samsung')
sys.path.append('/content/drive/My Drive/dataset')

# %%
#convert video to images

# !python3 "/content/drive/My Drive/samsung/tools/vid2img.py" "/content/drive/My Drive/dataset/video" "/content/images"
# Out:
# ******************** clapping ********************
# 100% 365/365 [06:52<00:00,  1.13s/it]
#
#
# ******************** dancing ********************
# 100% 415/415 [26:17<00:00,  3.80s/it]
#
#
# ******************** musical_instruments ********************
# 100% 354/354 [10:17<00:00,  1.75s/it]
#
#
# ******************** singing ********************
# 100% 425/425 [07:12<00:00,  1.02s/it]
#
#
# ******************** travel ********************
# 100% 585/585 [02:21<00:00,  4.14it/s]

# %%
#generate csv files

# !python3 "/content/drive/My Drive/samsung/labels/csv_gen.py"

#!python3 "/content/drive/My Drive/samsung/labels/train_csv_gen.py"
#!python3 "/content/drive/My Drive/samsung/labels/val_csv_gen.py"
# Out:
# ['dancing_320.mp4', 'dancing_247.mp4', 'dancing_164.mp4', 'dancing_313.mp4', 'dancing_165.mp4', 'dancing_260.mp4', 'dancing_314.mp4', 'dancing_261.mp4', 'dancing_315.mp4', 'dancing_166.mp4', 'dancing_338.mp4', 'dancing_127.mp4', 'dancing_7.mp4', 'dancing_3.mp4', 'dancing_4.mp4', 'dancing_163.mp4', 'dancing_145.mp4', 'dancing_18.mp4', 'dancing_29.mp4', 'dancing_325.mp4', 'dancing_19.mp4', 'dancing_324.mp4', 'dancing_37.mp4', 'dancing_40.mp4', 'dancing_60.mp4', 'dancing_331.mp4', 'dancing_41.mp4', 'dancing_61.mp4', 'dancing_62.mp4', 'dancing_140.mp4', 'dancing_158.mp4', 'dancing_44.mp4', 'dancing_42.mp4', 'dancing_63.mp4', 'dancing_258.mp4', 'dancing_45.mp4', 'dancing_332.mp4', 'dancing_51.mp4', 'dancing_43.mp4', 'dancing_64.mp4', 'dancing_65.mp4', 'dancing_139.mp4', 'dancing_81.mp4', 'dancing_82.mp4', 'dancing_93.mp4', 'dancing_326.mp4', 'dancing_94.mp4', 'dancing_50.mp4', 'dancing_128.mp4', 'dancing_114.mp4', 'dancing_115.mp4', 'dancing_106.mp4', 'dancing_137.mp4', 'dancing_107.mp4',
# ...

# %%
#generate labels

# !python3 "/content/drive/My Drive/samsung/tools/gen_label_CVAE.py"
# Out:
# {'clapping': 0, 'dancing': 1, 'musical_instruments': 2, 'singing': 3, 'travel': 4}
# 117
# /content/images/clapping/clapping_293
# 0/428, missing 0
# /content/images/clapping/clapping_294
# 1/428, missing 0
# /content/images/clapping/clapping_295
# 2/428, missing 0
# /content/images/clapping/clapping_296
# 3/428, missing 0
# /content/images/clapping/clapping_297
# 4/428, missing 0
# /content/images/clapping/clapping_298
# 5/428, missing 0
# /content/images/clapping/clapping_299
# 6/428, missing 0
# /content/images/clapping/clapping_300
# 7/428, missing 0
# /content/images/clapping/clapping_301
# 8/428, missing 0
# /content/images/clapping/clapping_302
# 9/428, missing 0
# /content/images/clapping/clapping_303
# 10/428, missing 0
# /content/images/clapping/clapping_304
# 11/428, missing 0
# /content/images/clapping/clapping_305
# 12/428, missing 0
# /content/images/clapping/clapping_306
# 13/428, missing 0
# /content/images/clapping/clapping_307
# 14/428, missing 0
# ...

# %%
#install tensorboardX

# !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 317kB 8.4MB/s
# ...

# %%
#give permission to execute script file

# !chmod +x "/content/drive/My Drive/samsung/scripts/train_tsm_CVAE_rgb_16f.sh"

# %%
#run the model

!"/content/drive/My Drive/samsung/scripts/train_tsm_CVAE_rgb_16f.sh"
# Out:
# CVAE: 5 classes
# storing name: TSM_CVAE_RGB_mobilenetv2_shift8_blockres_avg_segment16_e50
#
#     Initializing TSN with base model: mobilenetv2.
#     TSN Configurations:
#         input_modality:     RGB
#         num_segments:       16
#         new_length:         1
#         consensus_module:   avg
#         dropout_ratio:      0.5
#         img_feature_dim:    256
#
# => base model: mobilenetv2
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# video number:1316
# video number:342
# ...

# %%
# !rm -r '/content/images_test'
