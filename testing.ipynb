# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/My Drive/samsung')
sys.path.append('/content/drive/My Drive/dataset')

# %%
#convert test videos to images

# !python3 "/content/drive/My Drive/samsung/tools/vid2img.py" "/content/drive/My Drive/dataset/test" "/content/images_test"
# Out:
# ******************** clapping ********************
# *** convert has been done: /content/images_test/clapping/clapping_1
# 100% 1/1 [00:00<00:00, 4871.43it/s]
#
#
# ******************** dancing ********************
# *** convert has been done: /content/images_test/dancing/dancing_1
# *** convert has been done: /content/images_test/dancing/dancing_10
# *** convert has been done: /content/images_test/dancing/dancing_2
# *** convert has been done: /content/images_test/dancing/dancing_3
# *** convert has been done: /content/images_test/dancing/dancing_4
# *** convert has been done: /content/images_test/dancing/dancing_6
# *** convert has been done: /content/images_test/dancing/dancing_7
# *** convert has been done: /content/images_test/dancing/dancing_5
# *** convert has been done: /content/images_test/dancing/dancing_8
# *** convert has been done: /content/images_test/dancing/dancing_9
# 100% 10/10 [00:00<00:00, 28455.25it/s]
#
#
# ******************** musical_instruments ********************
# *** convert has been done: /content/images_test/musical_instruments/musical_instruments_1
# *** convert has been done: /content/images_test/musical_instruments/musical_instruments_10
# *** convert has been done: /content/images_test/musical_instruments/musical_instruments_2
# *** convert has been done: /content/images_test/musical_instruments/musical_instruments_3
# *** convert has been done: /content/images_test/musical_instruments/musical_instruments_5
# *** convert has been done: /content/images_test/musical_instruments/musical_instruments_8
#   0% 0/10 [00:00<?, ?it/s]*** convert has been done: /content/images_test/musical_instruments/musical_instruments_4
# *** convert has been done: /content/images_test/musical_instruments/musical_instruments_7
# *** convert has been done: /content/images_test/musical_instruments/musical_instruments_6
# *** convert has been done: /content/images_test/musical_instruments/musical_instruments_9
# 100% 10/10 [00:00<00:00, 6941.91it/s]
#
#
# ******************** singing ********************
# *** convert has been done: /content/images_test/singing/singing_1
# 100% 1/1 [00:00<00:00, 2849.39it/s]
#
#
# ******************** travel ********************
# *** convert has been done: /content/images_test/travel/travel_1
#   0% 0/23 [00:00<?, ?it/s]*** convert has been done: /content/images_test/travel/travel_10
# *** convert has been done: /content/images_test/travel/travel_11
# *** convert has been done: /content/images_test/travel/travel_12
# *** convert has been done: /content/images_test/travel/travel_13
# *** convert has been done: /content/images_test/travel/travel_14
# *** convert has been done: /content/images_test/travel/travel_16
# *** convert has been done: /content/images_test/travel/travel_17
# *** convert has been done: /content/images_test/travel/travel_18
# *** convert has been done: /content/images_test/travel/travel_19
# *** convert has been done: /content/images_test/travel/travel_2
# *** convert has been done: /content/images_test/travel/travel_21
# *** convert has been done: /content/images_test/travel/travel_20
# *** convert has been done: /content/images_test/travel/travel_15
# *** convert has been done: /content/images_test/travel/travel_22
# *** convert has been done: /content/images_test/travel/travel_3
# *** convert has been done: /content/images_test/travel/travel_5
# *** convert has been done: /content/images_test/travel/travel_6
# *** convert has been done: /content/images_test/travel/travel_7
# *** convert has been done: /content/images_test/travel/travel_8
# *** convert has been done: /content/images_test/travel/travel_4
# *** convert has been done: /content/images_test/travel/travel_23
# *** convert has been done: /content/images_test/travel/travel_9
# 100% 23/23 [00:00<00:00, 1833.14it/s]

# %%
#generate csv files

# !python3 "/content/drive/My Drive/samsung/labels/test_csv_gen.py"

# %%
#generate labels

# !python3 "/content/drive/My Drive/samsung/tools/test_gen_label.py"
# Out:
# {'clapping': 0, 'dancing': 1, 'musical_instruments': 2, 'singing': 3, 'travel': 4}
# 23
# /content/images_test/clapping/clapping_1
# 0/45, missing 0
# /content/images_test/dancing/dancing_1
# 1/45, missing 0
# /content/images_test/dancing/dancing_10
# 2/45, missing 0
# /content/images_test/dancing/dancing_2
# 3/45, missing 0
# /content/images_test/dancing/dancing_3
# 4/45, missing 0
# /content/images_test/dancing/dancing_4
# 5/45, missing 0
# /content/images_test/dancing/dancing_5
# 6/45, missing 0
# /content/images_test/dancing/dancing_6
# 7/45, missing 0
# /content/images_test/dancing/dancing_7
# 8/45, missing 0
# /content/images_test/dancing/dancing_8
# 9/45, missing 0
# /content/images_test/dancing/dancing_9
# 10/45, missing 0
# /content/images_test/musical_instruments/musical_instruments_1
# 11/45, missing 0
# /content/images_test/musical_instruments/musical_instruments_10
# 12/45, missing 0
# /content/images_test/musical_instruments/musical_instruments_2
# 13/45, missing 0
# /content/images_test/musical_instruments/musical_instruments_3
# 14/45, missing 0
# /content/images_test/musical_instruments/musical_instruments_4
# 15/45, missing 0
# /content/images_test/musical_instruments/musical_instruments_5
# 16/45, missing 0
# /content/images_test/musical_instruments/musical_instruments_6
# 17/45, missing 0
# /content/images_test/musical_instruments/musical_instruments_7
# 18/45, missing 0
# /content/images_test/musical_instruments/musical_instruments_8
# 19/45, missing 0
# /content/images_test/musical_instruments/musical_instruments_9
# 20/45, missing 0
# /content/images_test/singing/singing_1
# 21/45, missing 0
# /content/images_test/travel/travel_1
# 22/45, missing 0
# /content/images_test/travel/travel_10
# 23/45, missing 0
# /content/images_test/travel/travel_11
# 24/45, missing 0
# /content/images_test/travel/travel_12
# 25/45, missing 0
# /content/images_test/travel/travel_13
# 26/45, missing 0
# /content/images_test/travel/travel_14
# 27/45, missing 0
# /content/images_test/travel/travel_15
# 28/45, missing 0
# /content/images_test/travel/travel_16
# 29/45, missing 0
# /content/images_test/travel/travel_17
# 30/45, missing 0
# /content/images_test/travel/travel_18
# 31/45, missing 0
# /content/images_test/travel/travel_19
# 32/45, missing 0
# /content/images_test/travel/travel_2
# 33/45, missing 0
# /content/images_test/travel/travel_20
# 34/45, missing 0
# /content/images_test/travel/travel_21
# 35/45, missing 0
# /content/images_test/travel/travel_22
# 36/45, missing 0
# /content/images_test/travel/travel_23
# 37/45, missing 0
# /content/images_test/travel/travel_3
# 38/45, missing 0
# /content/images_test/travel/travel_4
# 39/45, missing 0
# /content/images_test/travel/travel_5
# 40/45, missing 0
# /content/images_test/travel/travel_6
# 41/45, missing 0
# /content/images_test/travel/travel_7
# 42/45, missing 0
# /content/images_test/travel/travel_8
# 43/45, missing 0
# /content/images_test/travel/travel_9
# 44/45, missing 0

# %%
#give permission to execute script file

# !chmod +x "/content/drive/My Drive/samsung/scripts/test_tsm_kinetics_rgb_8f.sh"

# %%
#test the model 

!"/content/drive/My Drive/samsung/scripts/test_tsm_kinetics_rgb_8f.sh"
# Out:
# CVAE: 5 classes
# => shift: True, shift_div: 8, shift_place: blockres
#
#     Initializing TSN with base model: resnet50.
#     TSN Configurations:
#         input_modality:     RGB
#         num_segments:       8
#         new_length:         1
#         consensus_module:   avg
#         dropout_ratio:      0.8
#         img_feature_dim:    256
#
# => base model: resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# 100% 97.8M/97.8M [00:00<00:00, 141MB/s]
# Adding temporal shift...
# => n_segment per stage: [8, 8, 8, 8]
# => Processing stage with 3 blocks residual
# => Using fold div: 8
# => Using fold div: 8
# => Using fold div: 8
# => Processing stage with 4 blocks residual
# => Using fold div: 8
# => Using fold div: 8
# => Using fold div: 8
# => Using fold div: 8
# => Processing stage with 6 blocks residual
# => Using fold div: 8
# => Using fold div: 8
# => Using fold div: 8
# => Using fold div: 8
# => Using fold div: 8
# => Using fold div: 8
# => Processing stage with 3 blocks residual
# => Using fold div: 8
# => Using fold div: 8
# => Using fold div: 8
# video number:45
# video 0 done, total 0/45, average 0.083 sec/video, moving Prec@1 80.000 Prec@5 100.000
# => Writing result to csv file: /content/drive/My Drive/samsung/labels/CVAE_test_results.csv
# [0.         1.         0.6        0.         0.86956522]
# upper bound: 0.8939130434782608
# -----Evaluation is finished------
# Class Accuracy 49.39%
# Overall Prec@1 80.00% Prec@5 100.00%
